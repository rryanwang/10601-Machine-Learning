# %%
import numpy as np
import pandas as pd

# %%
file = 'small_train.tsv'

# %%
dataset = pd.read_csv(file, sep='\t')

# %%
dataset
# Out:
#    Anti_satellite_test_ban Export_south_africa       Party
# 0                        n                   y    democrat
# 1                        n                   y  republican
# 2                        y                   y    democrat
# 3                        y                   y    democrat
# 4                        y                   y    democrat
# 5                        y                   y    democrat
# 6                        y                   y    democrat
# 7                        n                   y  republican
# 8                        y                   y    democrat
# 9                        n                   n  republican
# 10                       y                   y    democrat
# 11                       n                   y  republican
# 12                       y                   y    democrat
# 13                       n                   n  republican
# 14                       n                   y  republican
# ...

# %%
x = dataset.iloc[:, :-1].values

# %%
y = dataset.iloc[:, -1].values
